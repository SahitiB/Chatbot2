# %%
# New Chunker using Json file

import faiss
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.text_splitter import CharacterTextSplitter
import os
import json
import pickle
import tiktoken
from langchain.document_loaders import DirectoryLoader, PyPDFLoader
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.embeddings.openai import OpenAIEmbeddings

vector_store_name = 'acwd_faiss_store.pkl'
index_name= "acwd.index"
url_list = []

tokenizer = tiktoken.get_encoding('cl100k_base')
def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)
    

text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=200,
        chunk_overlap=10,
        length_function = len,
        separators=['\n\n', '\n', ' ', '']
    )

def process_file(file_path):
    chunks = []   
    metadatas = []
    # try:
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            data = json.loads(line)
            content = data['content']
            url = data['url']
           
            # Chunk the content and create embeddings
            splits = text_splitter.split_text(content)
            chunks.extend(splits)
            metadatas.extend([{"source": url}] * len(splits)) 
            print("added to index and url list for ", url)  
    
      #except Exception as e:
    #        print(f"Error processing file {file}: {e}")
       
    return chunks, metadatas


chunks, metadatas = process_file("items.jl")
print("done processing", len(chunks)) 

embeddings = HuggingFaceEmbeddings()
store = FAISS.from_texts(chunks, embeddings, metadatas=metadatas)    
faiss.write_index(store.index, index_name)
store.index = None
with open(vector_store_name, "wb") as f:
    pickle.dump(store, f)

print("created vector store ", vector_store_name)
# Out:
# added to index and url list for  https://acwd.org
# added to index and url list for  https://acwd.org/27/About-Us
# added to index and url list for  https://acwd.org/8/Services
# added to index and url list for  https://acwd.org/31/Connect-With-Us
# added to index and url list for  https://acwd.org/630/I-Want-To
# added to index and url list for  https://acwd.org/606/Advanced-Metering-Infrastructure-AMI
# added to index and url list for  https://acwd.org/waterclips
# added to index and url list for  https://acwd.org/145/Rebates
# added to index and url list for  https://acwd.org/117/Starting-Stopping-Service
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=131
# added to index and url list for  https://www.acwd.org/355/Current-Projects
# added to index and url list for  https://acwd.org/90/Board-of-Directors
# added to index and url list for  https://www.acwd.org/site/copyright
# added to index and url list for  https://www.acwd.org/accessibility
# added to index and url list for  https://www.acwd.org/689/Small-Diameter-Pipeline-Renewal-Program
# added to index and url list for  https://acwd.org/9/Job-Seekers
# added to index and url list for  https://www.acwd.org/contactus
# added to index and url list for  https://acwd.org/site/copyright
# added to index and url list for  https://acwd.org/accessibility
# added to index and url list for  https://www.acwd.org/Directory.aspx?did=27
# added to index and url list for  https://acwd.org/sitemap
# added to index and url list for  https://www.acwd.org/Directory.aspx
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=35
# added to index and url list for  https://acwd.org/734/Understanding-PFAS
# added to index and url list for  https://acwd.org/235/Well-Standards
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=48
# added to index and url list for  https://acwd.org/589/The-People-of-ACWD
# added to index and url list for  https://acwd.org/Bids.aspx
# added to index and url list for  https://www.acwd.org/faq.aspx?TID=51
# added to index and url list for  https://acwd.org/Faq.aspx?QID=196
# added to index and url list for  https://www.acwd.org/faq.aspx?TID=31
# added to index and url list for  https://acwd.org/forms.aspx?fid=109
# added to index and url list for  https://acwd.org/541/Transparency-Information
# added to index and url list for  https://acwd.org/AgendaCenter
# added to index and url list for  https://acwd.org/683/Your-Water
# added to index and url list for  https://acwd.org/directory.aspx?did=12
# added to index and url list for  https://acwd.org/contactus
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=23
# added to index and url list for  https://acwd.org/list.aspx?Mode=Subscribe
# added to index and url list for  https://acwd.org/faq.aspx?TID=51
# added to index and url list for  https://acwd.org/faq.aspx?TID=31
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_01252023-1262
# added to index and url list for  https://acwd.org/directory.aspx?EID=69
# added to index and url list for  https://alamedacountywaterdistrict.nextrequest.com/
# added to index and url list for  https://acwd.org/Directory.aspx?did=27
# added to index and url list for  https://acwd.org/Directory.aspx?did=18
# added to index and url list for  https://acwd.org/Directory.aspx?did=16
# added to index and url list for  https://acwd.org/Directory.aspx?did=25
# added to index and url list for  https://acwd.org/List.aspx
# added to index and url list for  https://acwd.org/Directory.aspx?did=24
# added to index and url list for  https://acwd.org/Directory.aspx?did=13
# added to index and url list for  https://acwd.org/Directory.aspx?did=4
# added to index and url list for  https://acwd.org/Directory.aspx?did=12
# added to index and url list for  https://acwd.org/Directory.aspx?DID=12
# added to index and url list for  https://acwd.org/Directory.aspx?did=19
# added to index and url list for  https://acwd.org/Directory.aspx?did=26
# added to index and url list for  https://acwd.org/Directory.aspx?did=11
# added to index and url list for  https://acwd.org/directory.aspx?EID=54
# added to index and url list for  https://acwd.org/forms.aspx?fid=118
# added to index and url list for  https://www.acwd.org/734/Understanding-PFAS
# added to index and url list for  https://acwd.org/directory.aspx?EID=48
# added to index and url list for  https://www.acwd.org/619/Local-State-Certified-Commercial-Laborat
# added to index and url list for  https://acwd.org/forms.aspx?fid=131
# added to index and url list for  https://www.acwd.org/164/Water-Hardness-Map
# added to index and url list for  https://acwd.org/directory.aspx?EID=55
# added to index and url list for  https://www.acwd.org/559/Lead-Copper-Tap-Sampling-Program
# added to index and url list for  https://acwd.org/forms.aspx?fid=79
# added to index and url list for  https://www.acwd.org/Archive.aspx?AMID=40
# added to index and url list for  https://acwd.org/forms.aspx?fid=154
# added to index and url list for  https://acwd.org/directory.aspx?EID=68
# added to index and url list for  https://acwd.org/forms.aspx?fid=160
# added to index and url list for  https://acwd.org/directory.aspx?EID=47
# added to index and url list for  https://acwd.org/forms.aspx?fid=97
# added to index and url list for  https://acwd.org/directory.aspx?EID=2
# added to index and url list for  https://acwd.org/directory.aspx?EID=26
# added to index and url list for  https://acwd.org/forms.aspx?fid=128
# added to index and url list for  https://acwd.org/forms.aspx?fid=132
# added to index and url list for  https://acwd.org/directory.aspx?EID=53
# added to index and url list for  https://acwd.org/Directory.aspx?DID=18
# added to index and url list for  https://acwd.org/directory.aspx?EID=39
# added to index and url list for  https://acwd.org/Directory.aspx?DID=16
# added to index and url list for  https://acwd.org/Directory.aspx?DID=25
# added to index and url list for  https://acwd.org/Directory.aspx?DID=24
# added to index and url list for  https://acwd.org/Directory.aspx?DID=13
# added to index and url list for  https://acwd.org/Directory.aspx?DID=11
# added to index and url list for  https://www.acwd.org/Archive.aspx
# added to index and url list for  https://www.acwd.org/700/Lead-Testing-for-Day-Care-Facilities
# added to index and url list for  https://acwd.org/directory.aspx?EID=38
# added to index and url list for  https://www.acwd.org/699/Lead-Sampling-Information-for-Schools
# added to index and url list for  https://acwd.org/directory.aspx?EID=37
# added to index and url list for  https://acwd.org/directory.aspx?EID=35
# added to index and url list for  https://acwd.org/forms.aspx?fid=82
# added to index and url list for  https://www.acwd.org/156/Annual-Water-Quality-Reports
# added to index and url list for  https://acwd.org/directory.aspx?EID=61
# added to index and url list for  https://acwd.org/directory.aspx?EID=12
# added to index and url list for  https://www.acwd.org/745/How-the-Main-Cleaning-Program-Works
# added to index and url list for  https://acwd.org/forms.aspx?fid=81
# added to index and url list for  https://acwd.org/forms.aspx?fid=159
# added to index and url list for  https://www.acwd.org/159/Main-Cleaning
# added to index and url list for  https://acwd.org/directory.aspx?EID=43
# added to index and url list for  https://www.acwd.org/167/Water-Quality-Self-Diagnostic-Tool
# added to index and url list for  https://acwd.org/forms.aspx?fid=158
# added to index and url list for  https://www.acwd.org/421/Water-Quality-FAQs
# added to index and url list for  https://acwd.org/directory.aspx?EID=16
# added to index and url list for  https://acwd.org/forms.aspx?fid=157
# added to index and url list for  https://www.acwd.org/155/Water-Quality
# added to index and url list for  https://acwd.org/directory.aspx?EID=15
# added to index and url list for  https://acwd.org/forms.aspx?fid=156
# added to index and url list for  https://acwd.org/directory.aspx?EID=24
# added to index and url list for  https://acwd.org/forms.aspx?fid=155
# added to index and url list for  https://acwd.org/directory.aspx?EID=60
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=119
# added to index and url list for  https://acwd.org/forms.aspx?fid=153
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=261
# added to index and url list for  https://acwd.org/directory.aspx?EID=59
# added to index and url list for  https://acwd.org/forms.aspx?fid=152
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=260
# added to index and url list for  https://acwd.org/directory.aspx?EID=57
# added to index and url list for  https://acwd.org/forms.aspx?fid=113
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=259
# added to index and url list for  https://acwd.org/directory.aspx?EID=52
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=39
# added to index and url list for  https://acwd.org/forms.aspx?fid=84
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=31
# added to index and url list for  https://acwd.org/directory.aspx?EID=9
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=39
# added to index and url list for  https://acwd.org/forms.aspx?fid=150
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=30
# added to index and url list for  https://acwd.org/directory.aspx?EID=56
# added to index and url list for  https://acwd.org/forms.aspx?fid=116
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=32
# added to index and url list for  https://acwd.org/forms.aspx?fid=83
# added to index and url list for  https://www.acwd.org/FAQ.aspx?TID=28
# added to index and url list for  https://acwd.org/directory.aspx?EID=28
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_09142023-1335
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_09142023-1333
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_09282023-1338
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_10122023-1344
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_10122023-1343
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_11092023-1350
# added to index and url list for  https://acwd.org/AgendaCenter/PreviousVersions/_12142023-1362
# added to index and url list for  https://acwd.org/list.aspx
# added to index and url list for  https://acwd.org/rss.aspx
# added to index and url list for  https://acwd.org/forms.aspx?FID=81
# added to index and url list for  https://acwd.org/faq.aspx?TID=18
# added to index and url list for  https://acwd.org/faq.aspx?TID=47
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=53&CID=All-0
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=1&CID=Home-1
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=1&CID=All-newsflash.xml
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=58&CID=Water-Conservation-22
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=58&CID=Home-Page-Calendar-14
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=58&CID=All-calendar.xml
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=92&CID=All-civicmedia.xml
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=51&CID=All-blog.xml
# added to index and url list for  https://www.acwd.org/199/Employee-Benefits-and-Programs
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=63&CID=Water-Safety-4
# added to index and url list for  https://www.acwd.org/203/Organizational-Charts-Salary-Schedules
# added to index and url list for  https://www.acwd.org/202/Job-Openings
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=63&CID=Important-Information-1
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=63&CID=All-0
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongWater-Resources-and-Conservationst-6
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongOperations-and-Water-Qualitystrong-5
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongLegal-Intergovernmental-and-Commun-4
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongFinancestrongthinspmdashthinspFina-2
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongEngineering-and-Information-Techno-3
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=strongBoard-of-Directorsstrongthinspmdas-1
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=65&CID=All-0
# added to index and url list for  https://acwd.org/RSSFeed.aspx?ModID=76&CID=All-0
# added to index and url list for  https://acwd.org/faq.aspx?TID=48
# added to index and url list for  https://acwd.org/faq.aspx?TID=37
# added to index and url list for  https://acwd.org/faq.aspx?TID=14
# added to index and url list for  https://acwd.org/faq.aspx?TID=39
# added to index and url list for  https://acwd.org/faq.aspx?TID=30
# added to index and url list for  https://www.acwd.org/485/Job-Descriptions
# added to index and url list for  https://www.acwd.org/200/Internships-Student-Work-Opportunities
# added to index and url list for  https://acwd.org/faq.aspx?TID=50
# added to index and url list for  https://acwd.org/faq.aspx?TID=38
# added to index and url list for  https://acwd.org/reportturf
# added to index and url list for  https://acwd.org/FormCenter/Water-Conservation-11/Voluntary-Reporting-Form-for-Functional--103
# added to index and url list for  https://acwd.org/FormCenter/Educators-Students-3/Tour-Request-Form-84
# added to index and url list for  https://acwd.org/faq.aspx?TID=20
# added to index and url list for  https://acwd.org/faq.aspx?TID=32
# added to index and url list for  https://acwd.org/faq.aspx?TID=16
# added to index and url list for  https://acwd.org/faq.aspx?TID=17
# added to index and url list for  https://acwd.org/faq.aspx?TID=15
# added to index and url list for  https://acwd.org/FAQ.aspx?QID=118
# added to index and url list for  https://acwd.org/faq.aspx?TID=28
# added to index and url list for  https://acwd.org/faq.aspx?TID=19
# added to index and url list for  https://acwd.org/faq.aspx?TID=44
# added to index and url list for  https://www.acwd.org/754/ACWDs-Water-Use-Efficiency-Efforts
# added to index and url list for  https://acwd.org/faq.aspx?TID=43
# added to index and url list for  https://www.acwd.org/145/Rebates
# added to index and url list for  https://acwd.org/faq.aspx?TID=42
# added to index and url list for  https://www.acwd.org/reportwaste
# added to index and url list for  https://acwd.org/faq.aspx?TID=34
# added to index and url list for  https://www.acwd.org/faq.aspx?TID=18
# added to index and url list for  https://acwd.org/faq.aspx?TID=46
# added to index and url list for  https://www.acwd.org/faq.aspx?TID=47
# added to index and url list for  https://www.acwd.org/faq.aspx?TID=48
# added to index and url list for  https://acwd.org/faq.aspx
# added to index and url list for  https://www.acwd.org/752/Water-Efficiency-Master-Plan
# added to index and url list for  https://portal.acwd.org/portal/default.aspx
# added to index and url list for  https://portal.acwd.org/portal/PrivacyPolicy.aspx
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=196
# added to index and url list for  https://portal.acwd.org/portal/TnC.aspx
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=61
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=16
# added to index and url list for  https://portal.acwd.org/portal/faq.aspx?LanguageCode=EN&isprelogin=false
# added to index and url list for  https://portal.acwd.org/portal/contact-us-connect-me_template.aspx?Ct=X70VqdSawzlNxAe8Do6fbGo%3d
# added to index and url list for  https://portal.acwd.org/portal/Demand_Response.aspx
# added to index and url list for  https://portal.acwd.org/portal/OuterSavingTips.aspx
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx?CID=18
# added to index and url list for  https://portal.acwd.org/portal/outer-service-request_template.aspx
# added to index and url list for  https://www.acwd.org/FormCenter/Water-Conservation-11/Commercial-Industrial-and-Institutional--105
# added to index and url list for  https://portal.acwd.org/portal/One-TimePayment.aspx
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=VsHxqUC4WAjZ8Q0mC%2fo56nE%3d
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=WJa2VliEtdY%2bKP418l0C7mM%3d
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx?CID=37
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=XSAP4NEljBABWpcMnbT6bdo%3d
# added to index and url list for  https://portal.acwd.org/portal/Error.aspx?aspxerrorpath=/portal/~/Error500.aspx
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx?CID=39
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx?CID=38
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx?CID=23
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=X70VqdSawzlNxAe8Do6fbGo%3d
# added to index and url list for  https://www.acwd.org/QuickLinks.aspx
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=X1hHEbDV4xBqTcV%2bMqN0wcz7
# added to index and url list for  https://portal.acwd.org/portal/FAQ.aspx?m=XG6CxFP6K4SnFd9U1CnI7QI%3d
# added to index and url list for  https://portal.acwd.org/portal/ForgetPassword
# added to index and url list for  https://portal.acwd.org/portal/ForgetUserName
# added to index and url list for  https://portal.acwd.org/portal/LoginSupport
# added to index and url list for  https://www.acwd.org/475/Partnerships
# added to index and url list for  https://www.acwd.org/120/News-Information
# added to index and url list for  https://www.acwd.org/189/Procurement-and-Contracts
# added to index and url list for  https://www.acwd.org/113/Bill-Payment-Options
# added to index and url list for  https://www.acwd.org/511/Finding-and-Fixing-Leaks
# added to index and url list for  https://www.acwd.org/148/Conservation-Calculators
# added to index and url list for  https://www.acwd.org/147/CIMIS
# added to index and url list for  https://www.acwd.org/146/Resources
# added to index and url list for  https://www.acwd.org/779/Drought-Video-Library
# added to index and url list for  https://www.acwd.org/515/Water-Conservation-Tips
# added to index and url list for  https://www.acwd.org/702/Sprinkler-System-Checklist
# added to index and url list for  https://www.acwd.org/376/Outdoor-Water-Saving-Tips
# added to index and url list for  https://www.acwd.org/139/ACWDs-Demonstration-Garden
# added to index and url list for  https://www.acwd.org/368/Lead-Fishing-Tackle-Exchange-Program
# added to index and url list for  https://www.acwd.org/367/Invasive-Mussels
# added to index and url list for  https://www.acwd.org/249/Vendor-Registration
# added to index and url list for  https://www.acwd.org/115/Water-Rates
# added to index and url list for  https://www.acwd.org/468/Service-Line-Coverage-Plan
# added to index and url list for  https://www.acwd.org/114/Obtaining-Returning-a-Hydrant-Meter
# added to index and url list for  https://www.acwd.org/171/Customer-Work-Request-Application
# added to index and url list for  https://www.acwd.org/798/Galvanized-Service-Line-Leaks
# added to index and url list for  https://www.acwd.org/quicklinks.aspx?CID=18
# added to index and url list for  https://www.acwd.org/763/Previous-Water-Rates-Processes
# added to index and url list for  https://www.acwd.org/621/Water-Rates-Process
# added to index and url list for  https://www.acwd.org/FormCenter/Customers-6/Hydrant-Meter-Read-Submission-79
# added to index and url list for  https://www.acwd.org/176/Standard-Drawings
# added to index and url list for  https://www.acwd.org/174/Standard-Specifications-Drawings
# added to index and url list for  https://www.acwd.org/175/Customer-Satisfaction-Surveys---Dev-Serv
# added to index and url list for  https://www.acwd.org/directory.aspx?did=11
# added to index and url list for  https://www.acwd.org/274/Engineering
# added to index and url list for  https://www.acwd.org/directory.aspx?did=19
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=128
# added to index and url list for  https://www.acwd.org/FormCenter/Developers--Consultants-2/Public-Water-System-Extensions-40
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=132
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=53
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=39
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=38
# added to index and url list for  https://www.acwd.org/280/Operations-Maintenance
# added to index and url list for  https://www.acwd.org/279/Office-of-the-General-Manager
# added to index and url list for  https://www.acwd.org/789/Human-Resources-Risk-Management
# added to index and url list for  https://www.acwd.org/275/Finance-Administration
# added to index and url list for  https://www.acwd.org/273/Water-Resources
# added to index and url list for  https://www.acwd.org/FormCenter/Developers-Consultants-2/Public-Water-System-Extensions-40
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=37
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=35
# added to index and url list for  https://www.acwd.org/Directory.aspx?DID=11
# added to index and url list for  https://www.acwd.org/FormCenter/Developers--Consultants-2/Customer-Work-Requests-53
# added to index and url list for  https://www.acwd.org/directory.aspx?did=20
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=97
# added to index and url list for  https://www.acwd.org/FormCenter/Developers-Consultants-2/Customer-Work-Requests-Job-Orders-53
# added to index and url list for  https://www.acwd.org/Archive.aspx?AMID=36
# added to index and url list for  https://www.acwd.org/763/9167/Previous-Water-Rates-Processes
# added to index and url list for  https://www.acwd.org/108/Community-Presentations
# added to index and url list for  https://www.acwd.org/104/Backflow-Prevention-Regulations
# added to index and url list for  https://www.acwd.org/103/Backflow-Device-Installation-Drawings
# added to index and url list for  https://www.acwd.org/106/Backflow-Prevention-Forms
# added to index and url list for  https://www.acwd.org/105/Backflow-Prevention-Explained
# added to index and url list for  https://www.acwd.org/102/Backflow-Prevention
# added to index and url list for  https://www.acwd.org/712/Diversion-Data
# added to index and url list for  https://www.acwd.org/385/Water-Treatment-Plant-No-2
# added to index and url list for  https://www.acwd.org/384/Regional-Water-System-Direct-Takeoff
# added to index and url list for  https://www.acwd.org/383/Newark-Desalination-Facility
# added to index and url list for  https://www.acwd.org/381/Blending-Facility
# added to index and url list for  https://www.acwd.org/101/Treatment-Plant-Descriptions
# added to index and url list for  https://www.acwd.org/378/State-Water-Project
# added to index and url list for  https://www.acwd.org/161/South-Bay-Aqueduct-Watershed-Protection
# added to index and url list for  https://www.acwd.org/379/San-Francisco-Regional-Water-System
# added to index and url list for  https://www.acwd.org/380/Niles-Cone-Groundwater-Basin
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=62
# added to index and url list for  https://www.acwd.org/directory.aspx?did=21
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=17
# added to index and url list for  https://www.acwd.org/35/Education
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=50
# added to index and url list for  https://www.acwd.org/directory.aspx?eid=55
# added to index and url list for  https://www.acwd.org/727/Free-Educational-Resources
# added to index and url list for  https://www.acwd.org/715/WaterClips-Student-Video-Contest
# added to index and url list for  https://www.acwd.org/191/Water-Treatment-Plant-Tours
# added to index and url list for  https://www.acwd.org/196/School-Theater-Programs
# added to index and url list for  https://www.acwd.org/Directory.aspx?DID=21
# added to index and url list for  https://www.acwd.org/FormCenter/Educators--Students-3/Free-Educational-Materials-Order-Form-34
# added to index and url list for  https://www.acwd.org/Directory.aspx?DID=25
# added to index and url list for  https://www.acwd.org/formcenter/educators-students-3/free-educational-materials-order-form-34
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=414
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=413
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=412
# added to index and url list for  https://www.acwd.org/FormCenter/Educators-Students-3/Free-Educational-Materials-Order-Form-34
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=410
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=55
# added to index and url list for  https://www.acwd.org/directory.aspx?EID=52
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=409
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=408
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=407
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=406
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=50
# added to index and url list for  https://www.acwd.org/FormCenter/Educators-Students-3/Tour-Request-Form-84
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=418
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=421
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=416
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=51
# added to index and url list for  https://www.acwd.org/772/Teacher-Resources-9th-and-12th-Grade
# added to index and url list for  https://www.acwd.org/773/8834/9th-and-12th-Grade-Interactive-GamesActi?activeLiveTab=widgets
# added to index and url list for  https://www.acwd.org/771/9th---12th-Grade-WorksheetsInformation
# added to index and url list for  https://www.acwd.org/770/8830/Teacher-Resources-7th---8th-Grade?activeLiveTab=widgets
# added to index and url list for  https://www.acwd.org/769/8829/7th-and-8th-Grade-Interactive-GamesActiv?activeLiveTab=widgets
# added to index and url list for  https://www.acwd.org/768/8827/7th---8th-Grade-WorksheetsInformation?activeLiveTab=widgets
# added to index and url list for  https://www.acwd.org/767/Pre-K---6th-Grade-Teacher-Resources
# added to index and url list for  https://www.acwd.org/764/Pre-K---6th-Grade-Interactive-GamesActiv
# added to index and url list for  https://www.acwd.org/765/Videos
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=79
# added to index and url list for  https://www.acwd.org/377/Alameda-Creek-Watershed-Local-Supplies
# added to index and url list for  https://www.acwd.org/98/Quarry-Lakes-Regional-Recreation-Area
# added to index and url list for  https://www.acwd.org/96/Mission-Statement
# added to index and url list for  https://www.acwd.org/750/Former-General-Managers
# added to index and url list for  https://www.acwd.org/766/8824/Pre-K---6th-Grade-WorksheetsInfo?activeLiveTab=widgets
# added to index and url list for  https://www.acwd.org/746/Former-Board-Members
# added to index and url list for  https://www.acwd.org/95/History
# added to index and url list for  https://www.acwd.org/Directory.aspx?EID=2
# added to index and url list for  https://www.acwd.org/272/Departments
# added to index and url list for  https://www.acwd.org/forms.aspx?fid=81
# added to index and url list for  https://www.acwd.org/List.aspx
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=53&CID=All-0
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=1&CID=Home-1
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=1&CID=All-newsflash.xml
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=58&CID=Water-Conservation-22
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=58&CID=Home-Page-Calendar-14
# added to index and url list for  https://www.acwd.org/RSSFeed.aspx?ModID=58&CID=All-calendar.xml
# ...
# added to index and url list for  https://acwd.org/FormCenter/Customers-6/Hydrant-Meter-Read-Submission-79
# added to index and url list for  https://acwd.org/Faq.aspx?QID=62
# added to index and url list for  https://acwd.org/Faq.aspx?TID=17
# added to index and url list for  https://acwd.org/FAQ.aspx?QID=127
# added to index and url list for  https://acwd.org/712/Diversion-Data
# added to index and url list for  https://acwd.org/385/Water-Treatment-Plant-No-2
# added to index and url list for  https://acwd.org/384/Regional-Water-System-Direct-Takeoff
# added to index and url list for  https://acwd.org/383/Newark-Desalination-Facility
# added to index and url list for  https://acwd.org/381/Blending-Facility
# added to index and url list for  https://acwd.org/101/Treatment-Plant-Descriptions
# added to index and url list for  https://acwd.org/378/State-Water-Project
# added to index and url list for  https://acwd.org/161/South-Bay-Aqueduct-Watershed-Protection
# added to index and url list for  https://acwd.org/379/San-Francisco-Regional-Water-System
# added to index and url list for  https://acwd.org/380/Niles-Cone-Groundwater-Basin
# added to index and url list for  https://acwd.org/377/Alameda-Creek-Watershed-Local-Supplies
# added to index and url list for  https://acwd.org/100/ACWDs-Water-Sources-Supplies
# added to index and url list for  https://acwd.org/98/Quarry-Lakes-Regional-Recreation-Area
# added to index and url list for  https://acwd.org/96/Mission-Statement
# added to index and url list for  https://acwd.org/750/Former-General-Managers
# added to index and url list for  https://acwd.org/746/Former-Board-Members
# added to index and url list for  https://acwd.org/95/History
# added to index and url list for  https://acwd.org/Directory.aspx?EID=2
# added to index and url list for  https://acwd.org/93/Fact-Sheet
# added to index and url list for  https://acwd.org/272/Departments
# added to index and url list for  https://acwd.org/91/Chronology-of-Significant-Events
# added to index and url list for  https://acwd.org/756/Ward-Based-Election-System
# added to index and url list for  https://acwd.org/351/Meetings-Agendas-Minutes
# added to index and url list for  https://acwd.org/directory.aspx?did=20
# added to index and url list for  https://acwd.org/Directory.aspx
# added to index and url list for  https://acwd.org/155/Water-Quality
# added to index and url list for  https://acwd.org/621/Water-Rates-Process
# added to index and url list for  https://acwd.org/133/Water-Conservation
# added to index and url list for  https://acwd.org/468/Service-Line-Coverage-Plan
# added to index and url list for  https://acwd.org/125/Emergency-Preparedness
# added to index and url list for  https://acwd.org/170/Development-Services
# added to index and url list for  https://acwd.org/AgendaCenter/Search/?term=&CIDs=3,2,4,5,6,&startDate=&endDate=&dateRange=&dateSelector=
# added to index and url list for  https://acwd.org/archive.aspx
# added to index and url list for  https://acwd.org/AgendaCenter/Search/?term=&CIDs=1,9,&startDate=&endDate=&dateRange=&dateSelector=
# added to index and url list for  https://acwd.org/directory.aspx?did=19
# added to index and url list for  https://acwd.org/directory.aspx?did=16
# added to index and url list for  https://acwd.org/directory.aspx?eid=9
# added to index and url list for  https://acwd.org/directory.aspx?did=10
# added to index and url list for  https://acwd.org/Faq.aspx?QID=204
# added to index and url list for  https://acwd.org/Faq.aspx?QID=181
# added to index and url list for  https://acwd.org/Faq.aspx?QID=180
# added to index and url list for  https://acwd.org/Faq.aspx?TID=18
# added to index and url list for  https://acwd.org/FAQ.aspx?TID=18
# added to index and url list for  https://acwd.org/FormCenter/Customers-6/Opt-Out-of-Future-HEIS-Mailings-74
# added to index and url list for  https://www.acwd.org/FormCenter/Water-Conservation-11/Water-Waste-Reporting-Form-72
# added to index and url list for  https://acwd.org/109/Customer-Service
# added to index and url list for  https://acwd.org/108/Community-Presentations
# added to index and url list for  https://acwd.org/102/Backflow-Prevention
# added to index and url list for  https://acwd.org/89/About-ACWD
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=34
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1341
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1389
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1288
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1340
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1287
# added to index and url list for  https://acwd.org/Calendar.aspx?EID=1339
# added to index and url list for  https://acwd.org/calendar.aspx?CID=14,22
# added to index and url list for  https://acwd.org/Faq.aspx?QID=128
# added to index and url list for  https://acwd.org/Faq.aspx?QID=60
# added to index and url list for  https://acwd.org/directory.aspx?did=21
# added to index and url list for  https://acwd.org/Faq.aspx?QID=127
# added to index and url list for  https://acwd.org/Faq.aspx?TID=15
# added to index and url list for  https://acwd.org/calendar.aspx?PREVIEW=YES&EID=1341
# added to index and url list for  https://acwd.org/calendar.aspx?PREVIEW=YES&EID=1389
# added to index and url list for  https://acwd.org/calendar.aspx?PREVIEW=YES&EID=1288
# added to index and url list for  https://acwd.org/calendar.aspx?PREVIEW=YES&EID=1340
# added to index and url list for  https://acwd.org/common/modules/iCalendar/iCalendar.aspx?feed=calendar&eventID=1340
# added to index and url list for  https://acwd.org/common/modules/iCalendar/iCalendar.aspx?feed=calendar&eventID=1288
# added to index and url list for  https://acwd.org/common/modules/iCalendar/iCalendar.aspx?feed=calendar&eventID=1389
# added to index and url list for  https://acwd.org/common/modules/iCalendar/iCalendar.aspx?feed=calendar&eventID=1341
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?AID=332
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?AID=336
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=1,5
# added to index and url list for  https://acwd.org/189/Procurement-and-Contracts
# added to index and url list for  https://acwd.org/475/Partnerships
# added to index and url list for  https://acwd.org/146/Resources
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=39
# added to index and url list for  https://acwd.org/formcenter
# added to index and url list for  https://acwd.org/135/Conservation-at-Work
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=38
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=1
# added to index and url list for  https://acwd.org/CivicAlerts.aspx
# added to index and url list for  https://acwd.org/CivicAlerts.aspx
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=3&ARC=11
# added to index and url list for  https://acwd.org/FormCenter/Share-a-Compliment-12/Report-a-Website-Issue-94
# added to index and url list for  https://www.acwd.org/606/Advanced-Metering-Infrastructure-AMI
# added to index and url list for  https://acwd.org/FormCenter/Share-a-Compliment-12
# added to index and url list for  https://www.acwd.org/Faq.aspx?TID=46
# added to index and url list for  https://acwd.org/FormCenter/Email-13/Email-AMI-Project-104
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=320
# added to index and url list for  https://acwd.org/FormCenter/Email-13
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=322
# added to index and url list for  https://acwd.org/FormCenter/Educators-Students-3
# added to index and url list for  https://www.acwd.org/Faq.aspx?QID=321
# added to index and url list for  https://acwd.org/FormCenter/Developers-Consultants-2/Fire-Flow-Test-Application-92
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=3&ARC=9
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=4&ARC=8
# added to index and url list for  https://acwd.org/FormCenter/Developers-Consultants-2
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=3&ARC=7
# added to index and url list for  https://acwd.org/CivicAlerts.aspx?CID=2&ARC=5
# added to index and url list for  https://acwd.org/FormCenter/Customers-6
# added to index and url list for  https://acwd.org/QuickLinks.aspx?CID=37
# done processing 38255
# created vector store  acwd_faiss_store.pkl

# %%
# Dec 16 chat bot

import pickle
import faiss
from langchain_community.chat_models import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

from langchain.chains import VectorDBQAWithSourcesChain
from langchain.chains import RetrievalQAWithSourcesChain
os.environ['OPENAI_API_KEY']='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'
OpenAI_key = os.environ.get("OPENAI_API_KEY")
vector_store_name = 'acwd_faiss_store.pkl'

# Load the FAISS index from disk.
index = faiss.read_index("acwd.index")

# Load the vector store from disk.
with open(vector_store_name, "rb") as f:
    store = pickle.load(f)

# merge the index and store
store.index = index

system_template = """
Your are an helpful AI assistant for Alameda County water department (ACWD). Website url is https://acwd.org. 
Try to be polite and helpful. Use the content of the transcript to answer the users question. Do not make up answers. 
If the question is not related to ACWD or water, DO NOT provide answers to the question and just reply 
"My primary function is to assist with inquiries related to the Alameda County Water District (ACWD). 
If you have any questions about ACWD services, please let me know, and I'll be glad to help!". 
----------------
{summaries}"""

messages = [
    SystemMessagePromptTemplate.from_template(system_template),
    HumanMessagePromptTemplate.from_template("{question}")
]
prompt = ChatPromptTemplate.from_messages(messages)

# Build the question answering chain.
llm = ChatOpenAI(openai_api_key=OpenAI_key, model_name="gpt-3.5-turbo", temperature=0.5, max_tokens=2256,
                 request_timeout=60)  
chain = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm,
    chain_type="stuff",
    #retriever=store.as_retriever(search_kwargs={'k':5}),
    retriever=store.as_retriever(),
    return_source_documents=True
    #chain_type_kwargs=chain_type_kwargs
)

# Run the chain.
query = "how should I pay my bill"
result = chain({"question": query})

# Print the answer and the sources.
print(f"Answer: {result['answer']}")
print(f"Sources: {result['sources']}")
# Out:
# Answer: You can pay your bill using any convenient payment method like Bank Account, MasterCard, Visa Card, Discover Card, ATM card, or Debit Card. Please confirm the details you provide on this page. You can find more information on bill payment on the ACWD website.
#
# Sources:
